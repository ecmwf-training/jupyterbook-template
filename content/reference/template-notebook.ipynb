# %% [markdown]
# # Notebook title

# %% [markdown]
# [![binder](https://mybinder.org/badge.svg)](https://mybinder.org/v2/gh/ecmwf-training/jupyterbook-template/main?labpath=content/reference/template-notebook.ipynb)
# [![kaggle](https://kaggle.com/static/images/open-in-kaggle.svg)](https://kaggle.com/kernels/welcome?src=https://github.com/ecmwf-training/jupyterbook-template/blob/main/content/reference/template-notebook.ipynb)
# [![colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ecmwf-training/jupyterbook-template/blob/main/content/reference/template-notebook.ipynb)

# %% [markdown]
# :::{note}
# This notebook can be run on free online platforms, such as Binder, Kaggle and Colab, or they can be accessed from GitHub. The links to run this notebook in these environments are provided here, but please note they are not supported by ECMWF.
# :::

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# *List the resources, accounts, and tools the learner needs **before** starting this notebook.*
#
# - **Prior knowledge expected:** *(e.g. completion of the Introduction to ERA5 notebook)*
# - **Related notebooks to complete first:** *(e.g. data-access tutorial)*
# - **Required tools / accounts:** *(e.g. CDS API key, Python ≥ 3.10, conda)*
#
# See also [How to view your Jupyter Book](../howto/review-book.md) for self-review steps before submission.

# %% [markdown]
# ## Target audience

# %% [markdown]
# *Specify the **scope and level** of skills assumed for the reader. This is distinct from **Prerequisites**: that section lists what to read or install first; this section describes who the notebook is for.*
#
# - **Skill level:** *Beginner / Intermediate / Advanced (or expert)*
# - **Role:** *e.g. researcher, forecaster, educator, student*
# - **Domain background assumed:** *e.g. Basic Python data analysis; Setting up or calibrating a hydrological model; Building a machine-learning model; Working knowledge of climate reanalyses*

# %% [markdown]
# ## Learning objectives 🎯

# %% [markdown]
# *This is a mandatory section for C3S training material*
#
# *Describe briefly what the learner/user can expect to learn in this notebook. Address the learner directly, for example:*
#
# You will use and adapt this Jupyter notebook template to create your own Jupyter notebook tutorials. Having followed this notebook, you will gain an understanding of the overall layout, common elements, metadata schema and best practices to apply in creating Jupyter notebook based learning resources for ECMWF.
#
# *If the notebook is targeted to a niche audience and is not already stated in a Jupyterbook or webpage where the notebook can be accessed, please summarise them here, or in a separate section.*

# %% [markdown]
# ## Method and data justification

# %% [markdown]
# *Briefly justify the method and data choice for this learning objective. Two to three sentences each is enough.*
#
# - **Why this method?** *State the assumptions and limits of the chosen approach (e.g. linear trend assumes stationarity; the resolution may smooth extreme events).*
# - **Why this dataset?** *Explain how the dataset fits the objective (temporal coverage, spatial resolution, provenance) and any known caveats.*
# - **Known limits:** *(e.g. valid only for the listed period or region; not suitable for sub-daily analyses).*

# %% [markdown]
# ## Prepare your environment

# %% [markdown]
# *Insert here any necessary instructions to set-up the environment of learners, any background information on data, projects, access to data catalogues, or preliminary steps necessary to run the notebooks. These may include instructions for installing packages, imports, etc.*

# %% [markdown]
# :::{important}
# All required dependencies should be included in the `environment.yml` file.
# :::

# %% [markdown]
# ### (Install and) Import libraries

# %%
# Install required libraries
# !pip install -q cdsapi

# %%
# Import your libraries here
import cdsapi

# %% [markdown]
# ### Setup credentials (optional)

# %% [markdown]
# If you have not setup your `~/.cdsapirc` file with your credentials, you can replace `None` with your credentials that can be found on the [how to api](https://cds.climate.copernicus.eu/how-to-api) page (you will need to log in to see your credentials).

# %%
# If you have already setup your .cdsapirc file you can leave this as None
cdsapi_key = None
cdsapi_url = None

# %% [markdown]
# ### Define your data request (optional)

# %% [markdown]
# *If your notebook retrieves data, describe (or link to) the request parameters and expected outputs here.*

# %%
dataset = "reanalysis-era5-single-levels-monthly-means"
filename = "dataset-filename.nc"
request = {
    "product_type": ["monthly_averaged_reanalysis"],
    "variable": ["2m_temperature"],
    "year": ["2023"],
    "month": ["06", "07", "08"],
    "time": ["00:00"],
    "data_format": "netcdf",
    "download_format": "unarchived",
}

client = cdsapi.Client(url=cdsapi_url, key=cdsapi_key)
client.retrieve(dataset, request).download({filename})

# %% [markdown]
# ## Main workflow
# Guideline:
# - below is only example header - please revise accordingly to your learning resources,
# - please add sensible comment on the high level summary/ function of the code whenever necessary

# %% [markdown]
# ### Load data and transformation

# %%
# your data loading and processing code here

# %% [markdown]
# ### Computational workflow

# %%
# your code for main computation or processing here

# %% [markdown]
# ### Visualisation and result intepretation

# %%
# your plotting / visualisation code here

# %% [markdown]
# ## Take home messages 📌

# %% [markdown]
# *In this section, summarise key take home messages.*
#
# - *Key message 1*
# - *Key message 2*
# - *Key message 3*

# %% [markdown]
# ## Transferability

# %% [markdown]
# *How transferable is this method/workflow to other parameters or variables? State which inputs the learner can safely change, and which are fixed by the method.*
#
# - *Can it be applied to a different region?*
# - *Is it applicable to other spatial and temporal resolutions?*
# - *Can other variables or products be substituted instead?*
# - *What aspects are fixed by the method and should not be modified?*

# %% [markdown]
# ## Validation (optional)

# %% [markdown]
# *Where applicable, briefly note how the result was sanity-checked (e.g. cross-checked against a published figure or journal, run on a different period, compared with an authoritative source) and any known limitations of the validation. Remove this section if not applicable.*

# %% [markdown]
# ## References

# %% [markdown]
# *Cite all datasets, publications, and reused figures used in this notebook. Use a DOI, an equivalent persistent identifier, or a stable URL with named authoritative provenance.*
#
# **Datasets**
# - *Dataset name (year). Provider. DOI / URL.*
#
# **Publications**
# - *Author, A. B. (Year). Title. Journal, vol(issue), pages. DOI.*
#
# **Reused figures**
# - *Figure source (URL), licence string.*

# %% [markdown]
# ## Glossary (optional)
#
# *Optional standalone glossary for definitions. Use this section only if the notebook introduces several novel terms; otherwise, define each term **on first use** in the prose (preferred).*
#
# - **Climatology** — *the average of a meteorological variable over a 30-year reference period.*
# - **Term 2** — *...*

# %% [markdown]
# ## Licence (optional / if applicable)
#
# *This notebook is distributed under the licence declared in the repository's `myst.yml` and `LICENSE` files. If a different licence applies to specific data, figures, or reused content within this notebook, state it here together with the source. Remove this section if not applicable.*
